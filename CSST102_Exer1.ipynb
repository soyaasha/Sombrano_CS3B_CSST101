# %% [markdown]
# **MACHINE LEARNING PIPELINE**

# %% [markdown]
# 1. Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# 2. Load and Understamnd the dataset

# %%
#convert to dataframe
df = pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.drop(columns='Id', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# 3. Visualize the dataset

# %% [markdown]
# *Histogram*

# %%
plt.hist(df['PetalLengthCm'], edgecolor='black', color='green')
plt.xlabel('PetalLength')
plt.ylabel('Number of rows')
plt.title('Histogram of PetalLengthCm')
plt.show()

# %%
plt.hist(df['SepalLengthCm'], edgecolor='black', color='pink')
plt.xlabel('SepalLength')
plt.ylabel('Number of rows')
plt.title('Histogram of SepalLengthCm')
plt.show()

# %%
fig, ax = plt.subplots(2,2, figsize=(8,8))

ax[0,0].hist(df["SepalLengthCm"], edgecolor='black', color='pink')
ax[0,1].hist(df["SepalWidthCm"], edgecolor='black', color='skyblue')
ax[1,0].hist(df["PetalLengthCm"], edgecolor='black', color='yellow')
ax[1,1].hist(df["PetalWidthCm"], edgecolor='black', color='orange')

ax[0,0].set_title("Sepal Length")
ax[0,1].set_title("Sepal Width")
ax[1,0].set_title("Petal Length")
ax[1,1].set_title("Petal Width")
# Out:
# Text(0.5, 1.0, 'Petal Width')

# %% [markdown]
# *Scatter Plot*

# %%
colors = {'Iris-setosa': 'red',
          'Iris-virginica': 'blue',
          'Iris-versicolor': 'green'}

# %%
plt.scatter(df['SepalLengthCm'],
            df['SepalWidthCm'],
            c=df['Species'].map(colors))

plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# %%
plt.scatter(df['SepalLengthCm'],
            df['PetalWidthCm'],
            c=df['Species'].map(colors))

plt.xlabel('Sepal Length')
plt.ylabel('Petal Width')
plt.show()

# %%
plt.scatter(df['PetalLengthCm'],
            df['PetalWidthCm'],
            c=df['Species'].map(colors))

plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.show()

# %% [markdown]
# 4. Split the dataset into a training set and testing set

# %%
#features
x = df.drop(columns=['Species']).values

#labels
y= df['Species' ].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=5)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120,)
# (30,)

# %% [markdown]
# 5. Create the model

# %% [markdown]
# *Choose machine learning algorithm*

# %%
knn =KNeighborsClassifier(n_neighbors=13)

# %% [markdown]
# *Train the model*

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %% [markdown]
# *Test the model*

# %%
y_pred = knn.predict(x_test)
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.9666666666666667

# %% [markdown]
# 6. Prediction

# %%
knn =KNeighborsClassifier(n_neighbors=13)
knn.fit(x_train,y_train)
knn.predict([[6,3,2,2]])
# Out:
# array(['Iris-setosa'], dtype=object)
