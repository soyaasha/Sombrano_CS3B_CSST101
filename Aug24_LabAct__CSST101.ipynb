# %% [markdown]
# 1.Student Data Frame

# %%
students <- data.frame(
  StudentID = c("S001", "S002", "S003", "S004", "S005"),
  Attendance = c(95, 72, 88, 79, 68),
  Grade = c(90, 70, 85, 77, 65),
  Risk = c("Low Risk", "High Risk", "Low Risk", "Moderate Risk", "High Risk")
)

print(students)
# Out:
#   StudentID Attendance Grade          Risk
# 1      S001         95    90      Low Risk
# 2      S002         72    70     High Risk
# 3      S003         88    85      Low Risk
# 4      S004         79    77 Moderate Risk
# 5      S005         68    65     High Risk

# %% [markdown]
# 2. Create Variables

# %%
attendace_rate <- 82
average_grade <- 78

print(attendace_rate)
print(average_grade)
# Out:
# [1] 82
# [1] 78

# %% [markdown]
# 3.Basic Calculations

# %%
quiz = 85
lab = 90
prjct = 88
exam = 80

final_grade = (quiz * 0.20) + (lab * 0.25) + (prjct * 0.25) + (exam * 0.30)

print(final_grade)
# Out:
# [1] 85.5

# %% [markdown]
# 4.Using Comparison Operations

# %%
attendance <- 70
grade <- 85

attendance < 75
grade < 75
attendance > 75
grade > 75
# Out:
# [1] TRUE
# [1] FALSE
# [1] FALSE
# [1] TRUE

# %% [markdown]
# 5. Using AND OR

# %%
attendance <- 70
grade <- 85


if (attendance <75 && grade < 75){
  print("Student is at Risk")}

if (attendance <75 || grade < 75){
  print("Student is at Risk")}
# Out:
# [1] "Student is at Risk"

# %% [markdown]
# 6. Simple If Statement

# %%
grade <- 80

if (grade >75){
  print("PASSED")
}else{
  print("FAILED")
}
# Out:
# [1] "PASSED"

# %% [markdown]
# 7. Multiple Conditions

# %%
grade <- 90

if (grade >=90){
  print("Excellent")

} else if (grade >= 85){
  print("Very Good")

} else if (grade >= 80){
  print("Good")

} else if (grade >=75){
  print("Passed")

} else if (grade < 75){
  print("Failed")
}
# Out:
# [1] "Excellent"

# %% [markdown]
# 8. Creating Functions

# %%
classify_grade <- function(grade){

if (grade >=90){
  print("Excellent")

} else if (grade >= 85){
  print("Very Good")

} else if (grade >= 80){
  print("Good")

} else if (grade >=75){
  print("Passed")

} else if (grade < 75){
  print("Failed")
}
}

grade <- 90
classify_grade(grade)
# Out:
# [1] "Excellent"

# %% [markdown]
# 9. Creating a Data Frame

# %%
students <- data.frame(
  StudentID = c("S001", "S002", "S003", "S004", "S005"),
  Attendance = c(95, 72, 88, 79, 68),
  Grade = c(90, 70, 85, 77, 65)
)

print(students)
# Out:
#   StudentID Attendance Grade
# 1      S001         95    90
# 2      S002         72    70
# 3      S003         88    85
# 4      S004         79    77
# 5      S005         68    65

# %% [markdown]
# 10. Adding a Classification Column

# %%
students$Performance <- ifelse(
  students$Grade >= 80,
  "Good",
  ifelse(
    students$Grade >= 75,
    "Passed", "Failed"
  )
)

students
# Out:
#   StudentID Attendance Grade Performance
# 1 S001      95         90    Good
# 2 S002      72         70    Failed
# 3 S003      88         85    Good
# 4 S004      79         77    Passed
# 5 S005      68         65    Failed

# %% [markdown]
# 11. Creating a Simple Rule-Based System

# %%
classify_risk <- function(attendance, grade){

if (attendance <75 && grade < 75){
  print("High Risk")
}else{
  print("Low Risk")
  }
}

attendance <- 75
grade <- 90

classify_risk(attendance, grade)
# Out:
# [1] "Low Risk"

# %% [markdown]
# 12. Add More Rules

# %%
classify_risk <- function(attendance, grade){

if (attendance <75 && grade < 75){
  print("High Risk")

}else if (attendance <85 || grade < 80){
  print("Moderate Risk")
}else if (attendance >85 && grade >80){
  print("Low Risk")
}
}


attendance <- 75
grade <- 90

classify_risk(attendance, grade)
# Out:
# [1] "Moderate Risk"

# %% [markdown]
# 13. Apply the Rule of Multiple Students

# %%
classify_risk <- function(attendance, grade){

if (attendance < 75 && grade < 75){
  return("High Risk")

}else if (attendance < 85 || grade < 80){
  return("Moderate Risk")
}else if (attendance >= 85 && grade >= 80){
  return("Low Risk")
} else {
  return("Undefined Risk")
}
}

students$Risk <- mapply(
  classify_risk,
  students$Attendance,
  students$Grade
)

students
# Out:
#   Student_ID Attendance Grade Risk
# 1 S001       95         90    Low Risk
# 2 S002       72         70    High Risk
# 3 S003       88         85    Low Risk
# 4 S004       79         77    Moderate Risk
# 5 S005       68         65    High Risk

# %% [markdown]
# 14. Count the Result

# %%
table(students$Risk)
# Out:
#     High Risk      Low Risk Moderate Risk
#             2             2             1

# %% [markdown]
# **Question & Answer**
# 1. How many students are High Risk? - **2**
# 2. How many are Moderate Risk? - **1**
# 3. How many are Low Risk? - **2**
# 4. Which group has the largest number of students? - **High Risk & Low Risk**

# %% [markdown]
# 15. Create Visualization

# %%
risk_counts <- table(students$Risk)

barplot(
  risk_counts,
  main = "Student Risk Classification",
  xlab = "Risk Level",
  ylab = "Number of Students",

)
# Out:
# Plot with title “Student Risk Classification”

# %% [markdown]
# **Question & Answer**
# 1. What does the graph show?
# - **The graph shows the number of students in each risk category: High Risk, Low Risk, and Moderate Risk.**
#
# 2. Which risk category has the most students?
# - **High Risk and Low Risk have the most students, with 2 students each.**
#
# 3. What action should the university take?
# - **The university should prioritize support for high-risk students, such as academic assistance, counseling, and regular monitoring. It should also provide support to low- and moderate-risk students to help prevent their situation from becoming worse.**

# %% [markdown]
# 16. Add a Recommendation

# %%
recommend_risk <- function(risk) {

  if (risk == "High Risk"){
  return("Immediate academic intervention")

  }else if (risk == "Moderate Risk"){
  return("Academic Monitoring")

  }else {
  return("Continue Regular Monitoring")
}
}

recommend_risk("High Risk")
# Out:
# [1] "Immediate academic intervention"

# %% [markdown]
# 17. Mini KRR System

# %%
student_id <- readline("Enter Student ID: ")
attendance <- as.numeric(readline( "Enter Attendance: "))
grade <- as.numeric(readline("Enter Grade: "))

student <- function(student_id, attendance, grade) {

  if (attendance < 75 & grade < 75) {
    risk <- "High Risk"
    recommendation <- "Immediate academic intervention"
  } else if (attendance < 85 | grade < 80) {
    risk <- "Moderate Risk"
    recommendation <- "Academic monitoring"
  } else if (attendance >= 85 & grade >= 80) {
    risk <- "Low Risk"
    recommendation <- "Continue regular monitoring"
  }

cat("\nStudent ID:", student_id, "\n")
cat("Attendance:", attendance,"\n")
cat("Grade:", grade, "\n\n")
cat("Risk Level:", risk, "\n\n")
cat("Recommendation:\n")
cat(recommendation, "\n")
}

student(student_id, attendance, grade)
# Out:
# Enter Student ID: S001
# Enter Attendance: 90
# Enter Grade: 95
#
# Student ID: S001
# Attendance: 90
# Grade: 95
#
# Risk Level: Low Risk
#
# Recommendation:
# Continue regular monitoring

# %% [markdown]
# 18. Final System
